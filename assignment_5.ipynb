# %% [markdown]
# Assignment 5
# =============
# <span style="color: lightsteelblue;">Udacity university | Deep Learning</span>
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.971014
# Nearest to history: interrelated, cay, background, galina, pattie, oxidation, exporter, drysdale,
# Nearest to up: freighters, leads, chelmsford, mart, sleepers, diger, plunder, leaky,
# Nearest to known: impotent, curiously, isla, russa, dressing, criminally, livy, narrator,
# Nearest to states: often, watery, bloodless, mesh, shreck, hampstead, accessible, evolutionism,
# Nearest to such: redshift, katharina, monogatari, rodan, ethnic, degradation, cleaning, lasts,
# Nearest to its: furious, reflectance, falsifiability, caveats, rapping, reaffirm, watt, fulton,
# Nearest to this: torrent, gwp, surprised, president, positioning, sri, screwed, nuh,
# Nearest to all: rho, reparation, confirm, gj, placate, xxxx, inconvenience, manipulating,
# Nearest to two: unrecorded, camping, dachshund, leyden, subtraction, cartooning, etymologically, senna,
# Nearest to b: nanotechnology, carbohydrate, devil, protestors, msc, router, opioids, mujahidin,
# Nearest to during: kabbalist, knock, kul, ludwig, commotion, roi, sean, buckinghamshire,
# Nearest to if: reverend, whipped, crammed, armchair, shiny, limitation, keeling, heidegger,
# Nearest to state: outcasts, broadcast, lems, lows, adoption, fathers, definitional, sucks,
# Nearest to his: becker, andy, investments, extracting, aylwin, commodity, coil, alienated,
# Nearest to on: impassioned, whyte, kickoffs, pointers, pluto, golems, borgia, angela,
# Nearest to no: kabbalist, sunburn, realistically, chem, strickland, fines, tabulation, primal,
# Average loss at step 2000: 4.366475
# Average loss at step 4000: 3.867647
# Average loss at step 6000: 3.789923
# Average loss at step 8000: 3.685042
# Average loss at step 10000: 3.616295
# Nearest to history: background, cay, lanterns, badgers, galina, pattie, reading, barbour,
# Nearest to up: mart, cultivation, succumbed, sleepers, fashionable, hierarchical, jeffersonian, plunder,
# Nearest to known: impotent, russa, dressing, well, rez, supplementary, borderlands, millikan,
# Nearest to states: samaritans, shreck, evolutionism, barcelona, megawati, batll, mesh, walking,
# Nearest to such: austen, monogatari, medgar, ethnic, abjad, plasmas, well, youngest,
# Nearest to its: their, the, his, some, caveats, socialist, reflectance, frictional,
# Nearest to this: it, the, that, which, any, an, gladly, compensating,
# Nearest to all: these, many, limb, reparation, gustave, princeton, declarations, chests,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to b: d, protestors, flirted, lyle, msc, lw, gees, devil,
# Nearest to during: roi, bata, strands, since, convenient, ludwig, duel, brazzaville,
# Nearest to if: must, firth, requires, bentham, limitation, when, stretch, lexical,
# Nearest to state: outcasts, broadcast, lows, competencies, sucks, iadb, delivering, turgot,
# Nearest to his: the, her, their, s, its, antiquaries, dissolves, him,
# Nearest to on: in, by, pointers, and, with, under, obsolete, nathan,
# Nearest to no: dvb, still, kabbalist, there, frege, convergent, demilitarized, fortify,
# Average loss at step 12000: 3.600943
# Average loss at step 14000: 3.573237
# Average loss at step 16000: 3.409701
# Average loss at step 18000: 3.454939
# Average loss at step 20000: 3.543596
# Nearest to history: badgers, background, lanterns, baptism, barbour, pattie, gulf, nsw,
# Nearest to up: fashionable, succumbed, cultivation, repelled, glance, keyboard, move, mart,
# Nearest to known: well, such, impotent, russa, used, borderlands, dressing, hdi,
# Nearest to states: walking, shreck, samaritans, barcelona, excessively, hosts, medina, batll,
# Nearest to such: well, austen, known, monogatari, many, other, abjad, snorri,
# Nearest to its: their, his, the, some, shortcuts, any, saints, bayes,
# Nearest to this: it, which, the, compensating, he, that, predating, universidade,
# Nearest to all: many, these, princeton, some, limb, afb, those, keeper,
# Nearest to two: three, five, four, six, seven, one, eight, zero,
# Nearest to b: d, angola, smuts, german, goethe, fsm, lw, ncbi,
# Nearest to during: after, roi, since, over, by, co, in, adowa,
# Nearest to if: when, but, must, requires, firth, though, kabbalists, starfighter,
# Nearest to state: outcasts, lows, delivering, broadcast, pratyeka, competencies, traders, donegal,
# Nearest to his: their, her, its, the, my, repertory, dissolves, huygens,
# Nearest to on: in, upon, at, oscillates, unspecific, camilo, agathocles, pluto,
# Nearest to no: demilitarized, there, fortify, searchable, who, it, not, a,
# Average loss at step 22000: 3.504841
# Average loss at step 24000: 3.491651
# Average loss at step 26000: 3.482649
# Average loss at step 28000: 3.480733
# Average loss at step 30000: 3.504113
# Nearest to history: badgers, hultsfred, baptism, nsw, background, barbour, chipmunk, lanterns,
# Nearest to up: him, glance, them, julia, succumbed, move, repelled, cultivation,
# Nearest to known: used, well, regarded, such, defined, dressing, hdi, borderlands,
# Nearest to states: walking, shreck, excessively, estrangement, bulgars, samaritans, hampstead, touchstone,
# Nearest to such: well, known, these, many, austen, other, alluvial, ike,
# Nearest to its: their, his, the, our, any, some, bayes, administratively,
# Nearest to this: it, which, what, there, any, some, the, he,
# Nearest to all: many, some, these, princeton, gap, limb, each, several,
# Nearest to two: three, four, one, five, seven, eight, six, nine,
# Nearest to b: d, satires, smuts, unrestricted, goethe, therapist, lw, minus,
# Nearest to during: after, in, since, through, before, roi, adowa, until,
# Nearest to if: when, though, where, requires, must, firth, starfighter, unsafe,
# Nearest to state: lows, donegal, vfl, lysine, broadcast, pointers, delivering, outcasts,
# Nearest to his: their, her, its, my, the, s, antiquaries, him,
# Nearest to on: upon, in, impassioned, antithesis, during, through, unspecific, oscillates,
# Nearest to no: a, still, searchable, little, any, there, problematic, demilitarized,
# Average loss at step 32000: 3.501834
# Average loss at step 34000: 3.496199
# Average loss at step 36000: 3.456364
# Average loss at step 38000: 3.301371
# Average loss at step 40000: 3.427333
# Nearest to history: mauro, hultsfred, boiling, background, sport, hoe, enver, list,
# Nearest to up: him, out, them, glance, cultivation, repelled, move, down,
# Nearest to known: used, such, regarded, well, defined, dressing, considered, honorifics,
# Nearest to states: walking, shreck, estrangement, touchstone, excessively, samaritans, hosts, bulgars,
# Nearest to such: well, known, these, including, ike, many, snorri, ridden,
# Nearest to its: their, his, the, her, keenan, kirov, affirmative, any,
# Nearest to this: which, it, the, that, unreasonable, some, bmw, any,
# Nearest to all: these, many, each, every, several, deuterocanonical, gap, limb,
# Nearest to two: three, four, six, five, seven, one, eight, nine,
# Nearest to b: d, UNK, r, panorama, c, minus, cummings, f,
# Nearest to during: after, since, until, before, adowa, at, digitalis, on,
# Nearest to if: when, where, though, stringent, requires, starfighter, englewood, that,
# Nearest to state: lows, delivering, vfl, government, donegal, recipient, angels, city,
# Nearest to his: her, their, its, the, my, antiquaries, him, s,
# Nearest to on: upon, unspecific, atrial, at, during, in, oscillates, tupac,
# Nearest to no: any, problematic, still, little, or, creutzfeldt, searchable, convergent,
# Average loss at step 42000: 3.439796
# Average loss at step 44000: 3.453194
# Average loss at step 46000: 3.448664
# Average loss at step 48000: 3.350558
# Average loss at step 50000: 3.379569
# Nearest to history: sport, boiling, hultsfred, enver, conectiva, list, milius, book,
# Nearest to up: out, him, them, down, glance, back, off, move,
# Nearest to known: used, regarded, such, well, defined, dressing, honorifics, considered,
# Nearest to states: estrangement, shreck, walking, touchstone, kingdom, excessively, samaritans, enjoined,
# Nearest to such: well, these, known, many, including, snorri, adhesive, part,
# Nearest to its: their, his, the, our, her, hydroelectric, monopolize, affirmative,
# Nearest to this: which, it, the, schmitz, he, swings, that, hers,
# Nearest to all: many, every, these, some, chipsets, various, both, princeton,
# Nearest to two: three, one, six, four, five, seven, eight, zero,
# Nearest to b: d, c, panorama, minus, r, f, pleasuredome, x,
# Nearest to during: after, before, in, since, when, until, digitalis, adowa,
# Nearest to if: when, though, where, while, before, although, starfighter, firth,
# Nearest to state: lows, vfl, recipient, government, delivering, donegal, traders, lysine,
# Nearest to his: her, their, its, my, the, your, our, antiquaries,
# Nearest to on: upon, in, at, impassioned, oscillates, atrial, hobbyist, about,
# Nearest to no: little, any, problematic, searchable, creutzfeldt, boas, pascha, brest,
# Average loss at step 52000: 3.438157
# Average loss at step 54000: 3.427839
# Average loss at step 56000: 3.437532
# Average loss at step 58000: 3.395832
# Average loss at step 60000: 3.392511
# Nearest to history: list, boiling, identifying, bully, milius, melanesian, philosophy, cva,
# Nearest to up: out, him, down, them, off, back, glance, repelled,
# Nearest to known: used, regarded, defined, considered, such, well, called, dressing,
# Nearest to states: countries, nations, kingdom, estrangement, walking, excessively, semivowel, shreck,
# Nearest to such: well, these, many, known, including, having, howls, adhesive,
# Nearest to its: their, his, the, her, our, loveland, affirmative, retailing,
# Nearest to this: it, which, what, some, that, there, the, ostracized,
# Nearest to all: these, every, many, some, both, those, various, any,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to b: d, n, f, r, m, middleware, c, minus,
# Nearest to during: after, before, since, in, although, following, when, digitalis,
# Nearest to if: when, though, where, before, although, since, so, while,
# Nearest to state: city, donegal, recipient, lows, government, campaigned, delivering, vfl,
# Nearest to his: her, their, its, my, the, our, your, hereby,
# Nearest to on: upon, in, through, unspecific, pluto, impassioned, protium, televised,
# Nearest to no: any, little, creutzfeldt, problematic, boas, hypatia, a, reserves,
# Average loss at step 62000: 3.243524
# Average loss at step 64000: 3.254533
# Average loss at step 66000: 3.402390
# Average loss at step 68000: 3.398509
# Average loss at step 70000: 3.356532
# Nearest to history: list, philosophy, boiling, book, bully, period, owls, habsburg,
# Nearest to up: out, them, off, back, him, down, glance, repelled,
# Nearest to known: used, regarded, such, defined, well, seen, dressing, considered,
# Nearest to states: countries, nations, kingdom, estrangement, excessively, walking, htp, ronnie,
# Nearest to such: well, these, known, many, adhesive, follows, other, dryness,
# Nearest to its: their, his, the, her, our, knesset, retailing, several,
# Nearest to this: it, which, the, there, that, some, another, any,
# Nearest to all: many, some, every, any, both, various, those, these,
# Nearest to two: three, six, four, seven, five, one, eight, zero,
# Nearest to b: d, f, n, x, r, minus, pleasuredome, pasiphae,
# Nearest to during: after, before, since, until, in, following, although, adowa,
# Nearest to if: when, though, where, before, although, while, since, after,
# Nearest to state: city, government, donegal, lows, recipient, traders, toms, hypothalamus,
# Nearest to his: her, their, its, my, our, your, the, hereby,
# Nearest to on: upon, through, in, champagne, under, impassioned, within, dagger,
# Nearest to no: little, any, problematic, searchable, creutzfeldt, nieuwe, jessie, boas,
# Average loss at step 72000: 3.375576
# Average loss at step 74000: 3.348978
# Average loss at step 76000: 3.313564
# Average loss at step 78000: 3.355944
# Average loss at step 80000: 3.378732
# Nearest to history: list, boiling, owls, philosophy, seuss, bully, communities, period,
# Nearest to up: out, off, them, down, him, back, glance, move,
# Nearest to known: used, regarded, defined, dressing, considered, seen, called, such,
# Nearest to states: kingdom, countries, nations, estrangement, shreck, excessively, state, walking,
# Nearest to such: well, these, known, follows, regarded, aries, including, adhesive,
# Nearest to its: their, his, her, our, the, your, hydroelectric, retailing,
# Nearest to this: it, which, the, that, mutated, what, unreasonable, some,
# Nearest to all: many, both, every, various, any, several, some, these,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to b: d, m, f, x, cummings, n, warns, pleasuredome,
# Nearest to during: after, before, in, until, when, since, despite, although,
# Nearest to if: when, though, before, since, where, although, cracked, after,
# Nearest to state: city, government, vfl, donegal, states, council, campaigned, deliberation,
# Nearest to his: her, their, its, my, your, our, the, squeeze,
# Nearest to on: upon, in, through, televised, impassioned, at, under, within,
# Nearest to no: little, any, creutzfeldt, slows, nieuwe, hypatia, pizarro, problematic,
# Average loss at step 82000: 3.408710
# Average loss at step 84000: 3.411350
# Average loss at step 86000: 3.391435
# Average loss at step 88000: 3.353499
# Average loss at step 90000: 3.367334
# Nearest to history: list, boiling, communities, bully, cva, journal, owls, melanesian,
# Nearest to up: out, off, them, back, down, him, glance, move,
# Nearest to known: used, regarded, such, seen, defined, dressing, described, possible,
# Nearest to states: nations, kingdom, countries, estrangement, us, excessively, claims, semivowel,
# Nearest to such: well, known, these, certain, follows, blimp, regarded, pineapple,
# Nearest to its: their, his, her, the, our, your, retailing, hydroelectric,
# Nearest to this: which, it, the, instead, some, another, unreasonable, reis,
# Nearest to all: many, several, some, both, every, various, these, any,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to b: d, n, p, r, warns, f, jasmine, pleasuredome,
# Nearest to during: after, in, before, until, within, since, when, at,
# Nearest to if: when, where, before, though, since, although, after, so,
# Nearest to state: city, government, exposures, westphalia, vfl, donegal, recipient, deliberation,
# Nearest to his: her, their, its, my, our, your, the, s,
# Nearest to on: upon, under, through, impassioned, within, in, at, ast,
# Nearest to no: little, any, nothing, problematic, zimbabwe, always, creutzfeldt, belgica,
# Average loss at step 92000: 3.398369
# Average loss at step 94000: 3.255082
# Average loss at step 96000: 3.358246
# Average loss at step 98000: 3.244689
# Average loss at step 100000: 3.357692
# Nearest to history: list, journal, vengeance, bully, boiling, owls, communities, book,
# Nearest to up: out, off, them, back, him, down, glance, typewriters,
# Nearest to known: regarded, such, used, defined, seen, described, possible, dressing,
# Nearest to states: nations, kingdom, countries, estrangement, ronnie, excessively, us, claims,
# Nearest to such: well, known, these, follows, certain, many, regarded, leftover,
# Nearest to its: their, his, her, the, our, retailing, your, knesset,
# Nearest to this: which, it, unreasonable, the, what, another, that, welded,
# Nearest to all: every, many, several, any, these, some, various, those,
# Nearest to two: three, five, four, six, seven, eight, one, zero,
# Nearest to b: d, kinsmen, contrabass, cessna, pemberton, walter, german, batgirl,
# Nearest to during: in, after, before, since, throughout, within, despite, following,
# Nearest to if: when, where, though, before, although, since, cracked, because,
# Nearest to state: city, amharic, government, blu, recipient, vfl, states, airline,
# Nearest to his: her, their, my, its, your, the, our, s,
# Nearest to on: upon, at, through, impassioned, in, within, dagger, packing,
# Nearest to no: little, any, nothing, problematic, nieuwe, slows, hypatia, boas,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
