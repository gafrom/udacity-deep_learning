# %% [markdown]
# Assignment 5
# =============
# <span style="color: lightsteelblue;">Udacity university | Deep Learning</span>
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 2 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.671812
# Nearest to on: frasier, rudder, plenum, rodeo, inexpensive, passant, maradona, mab,
# Nearest to many: masoretes, midline, butterfield, hatti, sahara, voyage, dea, tolerance,
# Nearest to such: yorker, thorough, cheeks, estas, popularized, ritual, keen, naghten,
# Nearest to five: persisting, hinayana, similarity, thieves, jeb, aur, morons, voluminous,
# Nearest to their: suppl, flaming, giza, granddaughter, alleging, jaya, purpose, eduke,
# Nearest to also: inactivity, marius, refinement, gesenius, neonatal, hearth, pseudolus, transducer,
# Nearest to in: erratic, election, participating, ccf, dtds, swallow, mastermind, boxcar,
# Nearest to time: state, dame, burbank, spiked, maximian, neoliberal, therapeutic, thinkpad,
# Nearest to when: curia, projekt, glenda, systemic, dissipation, discos, draco, apathetic,
# Nearest to for: staring, achieved, holies, antennae, stacks, delegate, dc, tactically,
# Nearest to while: benchers, contracts, courtesan, linz, kremlin, foals, innuendo, faramir,
# Nearest to that: alessandro, tamers, recounts, vote, endosymbiotic, yorkist, lacan, chestnuts,
# Nearest to after: arcology, gua, lemons, dragonfly, nails, biographical, pared, cryptic,
# Nearest to from: cabal, dredd, bitwise, overturned, musicals, oubangui, telecast, laurel,
# Nearest to with: lucretia, wreck, requirements, awakening, spotting, natura, ttir, jean,
# Nearest to six: ashore, graceful, plateau, intervened, devoting, bicycles, cove, friedman,
# Average loss at step 2000: 4.600401
# Average loss at step 4000: 4.098349
# Average loss at step 6000: 4.089616
# Average loss at step 8000: 4.001228
# Average loss at step 10000: 3.863770
# Nearest to on: in, and, from, ethelbert, heirs, under, roll, oxymoron,
# Nearest to many: radiometer, sounding, bean, masoretes, old, caston, several, all,
# Nearest to such: well, yorker, as, thorough, antiwar, cheeks, intrigued, autographs,
# Nearest to five: six, seven, three, four, zero, eight, two, one,
# Nearest to their: his, concentrate, them, eduke, concubinage, the, alleging, its,
# Nearest to also: that, this, only, formatted, quotation, austin, poirot, rotation,
# Nearest to in: on, and, from, by, with, of, steen, ethelbert,
# Nearest to time: state, dame, therapeutic, adobe, dyadic, use, postmodern, insuring,
# Nearest to when: crushed, projekt, deterrence, dyadic, minefields, claymore, pinker, excise,
# Nearest to for: to, with, and, achieved, lachlan, of, or, this,
# Nearest to while: contracts, morris, force, gniezno, benchers, worded, foals, kremlin,
# Nearest to that: which, this, it, alessandro, not, mink, sherwood, also,
# Nearest to after: determines, cryptic, biographical, hastened, maurya, zachary, arcology, gua,
# Nearest to from: and, on, in, with, oubangui, s, snowfall, caucasus,
# Nearest to with: and, for, to, from, between, in, by, captured,
# Nearest to six: four, three, five, seven, eight, zero, nine, one,
# Average loss at step 12000: 3.910563
# Average loss at step 14000: 3.869151
# Average loss at step 16000: 3.885195
# Average loss at step 18000: 3.884627
# Average loss at step 20000: 3.823513
# Nearest to on: in, heirs, ethelbert, with, sunglasses, diffeomorphism, quito, warehouse,
# Nearest to many: some, several, all, these, other, most, pds, old,
# Nearest to such: well, desert, antiwar, intrigued, known, cheeks, mwi, thorough,
# Nearest to five: seven, four, zero, eight, six, three, nine, two,
# Nearest to their: its, his, foreigners, the, other, snk, them, creditor,
# Nearest to also: which, it, only, not, that, this, bart, realization,
# Nearest to in: of, on, and, for, palgrave, barth, at, pluriform,
# Nearest to time: handy, adobe, insuring, exited, xe, coldcut, day, dame,
# Nearest to when: pencils, projekt, which, that, praying, pleated, sherpa, systemic,
# Nearest to for: of, lachlan, with, in, lamentations, framers, steen, wendy,
# Nearest to while: contracts, kremlin, force, benchers, morris, linz, courtesan, brandt,
# Nearest to that: which, this, it, grenade, no, patchwork, zoomed, mink,
# Nearest to after: aluminum, jacobi, cryptic, biographical, wideband, he, barley, hastened,
# Nearest to from: and, abbreviated, actus, diet, vehicle, oubangui, conservatively, wave,
# Nearest to with: by, between, galleon, for, microcomputer, and, lucretia, on,
# Nearest to six: eight, seven, nine, five, four, three, zero, one,
# Average loss at step 22000: 3.794521
# Average loss at step 24000: 3.789710
# Average loss at step 26000: 3.735765
# Average loss at step 28000: 3.819073
# Average loss at step 30000: 3.710145
# Nearest to on: in, collaborating, through, under, enzymes, at, midgard, reboot,
# Nearest to many: some, several, these, most, all, were, are, other,
# Nearest to such: well, mwi, prohibitive, many, serapeum, known, awarding, realtime,
# Nearest to five: four, six, three, seven, eight, two, zero, nine,
# Nearest to their: its, his, her, the, eco, them, creditor, some,
# Nearest to also: which, arabidopsis, now, often, bart, that, not, rosamund,
# Nearest to in: from, of, on, sept, since, and, advancing, affray,
# Nearest to time: sire, handy, least, adobe, consequence, contras, exited, eff,
# Nearest to when: but, that, if, where, which, pleated, praying, pencils,
# Nearest to for: lachlan, speght, with, or, leningrad, oiled, raucous, congratulated,
# Nearest to while: contracts, and, destruct, oneida, although, courtesan, brandt, sg,
# Nearest to that: which, but, when, where, this, however, not, also,
# Nearest to after: before, during, with, aluminum, jacobi, since, until, from,
# Nearest to from: in, with, and, renditions, oubangui, pb, after, vehicle,
# Nearest to with: between, by, from, after, scaled, schumann, into, for,
# Nearest to six: seven, eight, five, four, three, zero, nine, two,
# Average loss at step 32000: 3.724259
# Average loss at step 34000: 3.658817
# Average loss at step 36000: 3.810609
# Average loss at step 38000: 3.786239
# Average loss at step 40000: 3.770417
# Nearest to on: in, through, at, upon, honest, collaborating, wrong, under,
# Nearest to many: some, several, these, most, were, all, those, are,
# Nearest to such: well, known, many, overrun, mwi, realtime, triplet, dynamical,
# Nearest to five: four, three, seven, eight, six, zero, two, one,
# Nearest to their: its, his, them, the, her, these, some, foreigners,
# Nearest to also: often, now, which, rosamund, zimmermann, it, commonly, been,
# Nearest to in: since, on, of, and, from, during, soloists, trophy,
# Nearest to time: least, adobe, eff, handy, ebola, hyperion, consequence, name,
# Nearest to when: if, where, but, from, by, that, praying, after,
# Nearest to for: of, lachlan, with, cedilla, meme, and, topper, clinics,
# Nearest to while: but, although, before, copying, contracts, brandt, kremlin, worded,
# Nearest to that: which, however, if, it, this, but, conveying, what,
# Nearest to after: during, before, following, since, until, when, jacobi, aluminum,
# Nearest to from: and, into, in, when, with, before, rubinstein, between,
# Nearest to with: and, between, for, by, of, lucretia, from, into,
# Nearest to six: seven, eight, four, three, five, nine, zero, one,
# Average loss at step 42000: 3.711394
# Average loss at step 44000: 3.673933
# Average loss at step 46000: 3.739252
# Average loss at step 48000: 3.784488
# Average loss at step 50000: 3.776621
# Nearest to on: in, upon, reboot, kuan, at, through, accomplishing, quito,
# Nearest to many: some, several, most, these, those, all, other, were,
# Nearest to such: well, known, stifled, triplet, result, seen, symmetries, serapeum,
# Nearest to five: four, three, six, seven, eight, zero, one, nine,
# Nearest to their: its, his, her, them, the, these, other, eusebius,
# Nearest to also: now, often, which, that, always, still, bribe, zimmermann,
# Nearest to in: on, during, of, since, within, pizan, dictionary, from,
# Nearest to time: least, period, consequence, end, adobe, hyperion, handy, eff,
# Nearest to when: but, where, that, during, while, if, after, before,
# Nearest to for: lachlan, with, congratulated, of, martha, jirga, include, and,
# Nearest to while: when, although, but, and, brandt, contracts, civilizations, kremlin,
# Nearest to that: which, however, when, it, although, what, this, if,
# Nearest to after: before, during, until, following, when, aluminum, later, he,
# Nearest to from: into, when, pb, before, after, beekeepers, obstinate, warns,
# Nearest to with: between, for, pseudo, using, and, buckminster, artform, dpp,
# Nearest to six: seven, eight, four, three, five, nine, zero, one,
# Average loss at step 52000: 3.776180
# Average loss at step 54000: 3.746306
# Average loss at step 56000: 3.679432
# Average loss at step 58000: 3.709815
# Average loss at step 60000: 3.758538
# Nearest to on: through, upon, in, tigrinya, arbuthnot, frightened, accomplishing, atanasoff,
# Nearest to many: some, several, other, various, all, these, most, were,
# Nearest to such: well, known, result, stifled, as, involving, pseudopods, symmetries,
# Nearest to five: six, seven, four, eight, three, zero, nine, two,
# Nearest to their: its, his, her, the, them, these, some, many,
# Nearest to also: which, now, that, sometimes, often, rosamund, jehoahaz, fatalism,
# Nearest to in: since, of, queensberry, dictionary, socio, on, technetium, unheard,
# Nearest to time: period, least, same, year, end, adobe, consequence, years,
# Nearest to when: after, while, because, during, over, however, if, but,
# Nearest to for: lachlan, harrier, of, marksmanship, antithesis, bian, chari, paxton,
# Nearest to while: although, when, but, and, among, including, before, however,
# Nearest to that: which, however, although, this, grenade, what, when, it,
# Nearest to after: before, during, when, following, until, over, spiritualist, next,
# Nearest to from: into, through, before, since, behind, mahommed, pb, cesare,
# Nearest to with: between, using, lucretia, pseudo, and, obadiah, scaled, into,
# Nearest to six: eight, five, four, seven, three, nine, two, zero,
# Average loss at step 62000: 3.710774
# Average loss at step 64000: 3.690798
# Average loss at step 66000: 3.730417
# Average loss at step 68000: 3.731206
# Average loss at step 70000: 3.743665
# Nearest to on: in, through, upon, at, of, reboot, sands, from,
# Nearest to many: some, several, various, both, other, these, were, those,
# Nearest to such: well, known, seen, serapeum, including, result, subjecting, triplet,
# Nearest to five: four, six, three, eight, seven, zero, two, nine,
# Nearest to their: its, his, her, our, other, the, them, your,
# Nearest to also: now, still, often, which, bribe, sometimes, extremely, tomasz,
# Nearest to in: during, on, until, shrink, since, of, within, pressburg,
# Nearest to time: least, period, same, end, eff, year, point, coldcut,
# Nearest to when: but, if, where, however, because, while, after, before,
# Nearest to for: lachlan, of, bian, harrier, meme, anonymity, appian, lemming,
# Nearest to while: although, when, and, but, however, before, including, cucurbitaceae,
# Nearest to that: which, however, this, although, no, but, where, when,
# Nearest to after: before, during, until, when, following, since, later, from,
# Nearest to from: into, behind, before, through, denning, during, by, obstinate,
# Nearest to with: between, and, using, waterproof, by, subdivided, theobald, multiparty,
# Nearest to six: eight, seven, four, three, five, nine, two, zero,
# Average loss at step 72000: 3.726495
# Average loss at step 74000: 3.683926
# Average loss at step 76000: 3.610117
# Average loss at step 78000: 3.710827
# Average loss at step 80000: 3.645658
# Nearest to on: through, upon, collaborating, in, reboot, atanasoff, disqualification, heirs,
# Nearest to many: some, several, various, most, all, both, among, other,
# Nearest to such: well, known, result, tagging, subjecting, utilities, symmetries, botched,
# Nearest to five: four, seven, zero, three, six, eight, nine, one,
# Nearest to their: its, his, her, the, our, them, these, your,
# Nearest to also: still, often, now, sometimes, bribe, which, commonly, licensing,
# Nearest to in: during, until, on, since, tangible, unguarded, recapitulation, postcard,
# Nearest to time: least, period, end, year, point, eff, same, thing,
# Nearest to when: if, because, during, after, but, while, where, since,
# Nearest to for: lachlan, congratulated, harrier, pleas, bian, chari, clinics, plagued,
# Nearest to while: and, although, however, when, including, but, among, though,
# Nearest to that: which, however, where, although, when, this, who, what,
# Nearest to after: before, during, following, until, since, when, over, through,
# Nearest to from: into, acknowledgement, through, cesare, when, canis, actus, print,
# Nearest to with: between, pseudo, using, when, lucretia, elitist, exhorts, consisting,
# Nearest to six: eight, seven, four, five, three, zero, nine, two,
# Average loss at step 82000: 3.687479
# Average loss at step 84000: 3.661921
# Average loss at step 86000: 3.718036
# Average loss at step 88000: 3.435926
# Average loss at step 90000: 3.238490
# Nearest to on: upon, through, in, off, bays, parody, about, inverted,
# Nearest to many: some, several, various, these, all, both, other, most,
# Nearest to such: well, known, symmetries, involving, result, subjecting, including, utilities,
# Nearest to five: four, six, three, seven, eight, two, nine, zero,
# Nearest to their: his, its, her, the, both, own, these, our,
# Nearest to also: still, which, often, now, campaigns, however, that, never,
# Nearest to in: from, where, on, until, commemorative, for, five, odense,
# Nearest to time: least, period, eff, end, age, year, contras, years,
# Nearest to when: because, after, while, where, if, before, during, but,
# Nearest to for: lachlan, after, yeomen, appian, monument, in, membered, of,
# Nearest to while: when, although, but, however, though, and, before, where,
# Nearest to that: which, however, although, where, when, what, if, because,
# Nearest to after: before, during, when, until, following, since, from, through,
# Nearest to from: after, in, into, while, ou, multimate, before, around,
# Nearest to with: between, longbows, accessibility, toughest, inordinate, consulate, into, had,
# Nearest to six: seven, eight, three, four, five, two, nine, zero,
# Average loss at step 92000: 3.480542
# Average loss at step 94000: 3.538930
# Average loss at step 96000: 3.639064
# Average loss at step 98000: 3.646738
# Average loss at step 100000: 3.623518
# Nearest to on: upon, through, in, near, at, tigrinya, of, suffers,
# Nearest to many: some, several, various, these, all, both, other, most,
# Nearest to such: well, result, many, symmetries, known, involving, various, subjecting,
# Nearest to five: four, three, six, eight, seven, zero, two, nine,
# Nearest to their: its, her, his, our, these, the, both, several,
# Nearest to also: now, often, still, which, that, zimmermann, ishaq, however,
# Nearest to in: of, and, from, during, on, since, until, within,
# Nearest to time: period, least, year, age, point, insuring, eff, end,
# Nearest to when: however, because, while, although, if, after, during, where,
# Nearest to for: of, lachlan, provides, within, commercial, after, bian, himalayan,
# Nearest to while: however, although, when, but, because, though, where, before,
# Nearest to that: which, however, although, this, if, where, because, what,
# Nearest to after: before, during, following, until, when, through, while, despite,
# Nearest to from: into, in, through, of, across, within, around, after,
# Nearest to with: between, pseudo, through, and, to, rapidly, using, peebles,
# Nearest to six: eight, seven, four, five, three, nine, two, one,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
